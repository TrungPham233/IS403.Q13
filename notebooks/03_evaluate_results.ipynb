# %% [markdown]
# # 03 - Evaluate results
#
# Review the test-set metrics written by the training pipeline and export a comparison chart for the portfolio.

# %%
import pandas as pd
metrics = pd.read_csv('../artifacts/model_metrics.csv')
metrics.sort_values('roc_auc', ascending=False)

# %%
import sys
# !{sys.executable} -m src.report --metrics ../artifacts/model_metrics.csv --output-dir ../reports/figures
