# %% [markdown]
# # 01 - Data understanding
#
# This notebook reviews the Home Credit `application_train.csv` dataset used in the project. Data remains local and is not committed to Git.

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path('../data/raw/application_train.csv')
data = pd.read_csv(DATA_PATH)
data.shape, data['TARGET'].value_counts(normalize=True).rename('share')

# %%
missing = data.isna().mean().sort_values(ascending=False)
missing.head(15).to_frame('missing_rate')
