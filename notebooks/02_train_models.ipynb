# %% [markdown]
# # 02 - Model training
#
# This notebook invokes the same clean pipeline used by the repository CLI. It uses stratified splits, train-only preprocessing, and class-weighted models; it does not use SMOTE.

# %%
import sys
from pathlib import Path

ROOT = Path('..').resolve()
sys.path.insert(0, str(ROOT))

# %%
# Development smoke test. Remove --sample-size for the full run.
# !{sys.executable} -m src.train --data ../data/raw/application_train.csv --sample-size 50000 --output-dir ../artifacts
